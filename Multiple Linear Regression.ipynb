# %% [markdown]
# # *Importing all neccessary libraries*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %% [markdown]
# ***Exploratory Data Analysis***

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 127

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9873, 6)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace = True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Data Transformation
#
# - **Encoding**
# - **Scaling**

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9868              1               49                        Yes            4
# 9869              7               64                        Yes            8
# 9870              6               83                        Yes            8
# 9871              9               97                        Yes            7
# 9872              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9868                                 2               23.0
# 9869                                 5               58.0
# 9870                                 5               74.0
# 9871                                 0               95.0
# 9872                                 1               64.0
#
# [9873 rows x 6 columns]

# %%
df = pd.get_dummies(data=df, columns=['Extracurricular Activities'],dtype=int)
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9868              1               49            4
# 9869              7               64            8
# 9870              6               83            8
# 9871              9               97            7
# 9872              7               74            8
#
#       Sample Question Papers Practiced  Performance Index  \
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9868                                 2               23.0
# 9869                                 5               58.0
# 9870                                 5               74.0
# 9871                                 0               95.0
# 9872                                 1               64.0
#
#       Extracurricular Activities_No  Extracurricular Activities_Yes
# 0                                 0                               1
# 1                                 1                               0
# 2                                 0                               1
# 3                                 0                               1
# 4                                 1                               0
# ...                             ...                             ...
# 9868                              0                               1
# 9869                              0                               1
# 9870                              0                               1
# 9871                              0                               1
# 9872                              1                               0
#
# [9873 rows x 7 columns]

# %% [markdown]
# ***Defining x and y***

# %%
x = df.drop(columns = ['Performance Index'])
y = df['Performance Index']

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9868              1               49            4
# 9869              7               64            8
# 9870              6               83            8
# 9871              9               97            7
# 9872              7               74            8
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 0                                    1                              0
# 1                                    2                              1
# 2                                    2                              0
# 3                                    2                              0
# 4                                    5                              1
# ...                                ...                            ...
# 9868                                 2                              0
# 9869                                 5                              0
# 9870                                 5                              0
# 9871                                 0                              0
# 9872                                 1                              1
#
#       Extracurricular Activities_Yes
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 9868                               1
# 9869                               1
# 9870                               1
# 9871                               1
# 9872                               0
#
# [9873 rows x 6 columns]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9868    23.0
# 9869    58.0
# 9870    74.0
# 9871    95.0
# 9872    64.0
# Name: Performance Index, Length: 9873, dtype: float64

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9868              1               49            4
# 9869              7               64            8
# 9870              6               83            8
# 9871              9               97            7
# 9872              7               74            8
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 0                                    1                              0
# 1                                    2                              1
# 2                                    2                              0
# 3                                    2                              0
# 4                                    5                              1
# ...                                ...                            ...
# 9868                                 2                              0
# 9869                                 5                              0
# 9870                                 5                              0
# 9871                                 0                              0
# 9872                                 1                              1
#
#       Extracurricular Activities_Yes
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 9868                               1
# 9869                               1
# 9870                               1
# 9871                               1
# 9872                               0
#
# [9873 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x = pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0          0.775566         1.706168     1.454025
# 1         -0.383205         0.724912    -1.491315
# 2          1.161822        -1.064438     0.275889
# 3          0.003052        -1.006717    -0.902247
# 4          0.775566         0.320865     0.864957
# ...             ...              ...          ...
# 9868      -1.541976        -1.179880    -1.491315
# 9869       0.775566        -0.314066     0.864957
# 9870       0.389309         0.782633     0.864957
# 9871       1.548079         1.590727     0.275889
# 9872       0.775566         0.263144     0.864957
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 0                            -1.249715                      -1.010078
# 1                            -0.900925                       0.990022
# 2                            -0.900925                      -1.010078
# 3                            -0.900925                      -1.010078
# 4                             0.145444                       0.990022
# ...                                ...                            ...
# 9868                         -0.900925                      -1.010078
# 9869                          0.145444                      -1.010078
# 9870                          0.145444                      -1.010078
# 9871                         -1.598505                      -1.010078
# 9872                         -1.249715                       0.990022
#
#       Extracurricular Activities_Yes
# 0                           1.010078
# 1                          -0.990022
# 2                           1.010078
# 3                           1.010078
# 4                          -0.990022
# ...                              ...
# 9868                        1.010078
# 9869                        1.010078
# 9870                        1.010078
# 9871                        1.010078
# 9872                       -0.990022
#
# [9873 rows x 6 columns]

# %% [markdown]
# # Splitting the data into training and test part

# %%
df.head(10)
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
# 5              3               78            9
# 6              7               73            5
# 7              8               45            4
# 8              5               77            8
# 9              4               89            4
#
#    Sample Question Papers Practiced  Performance Index  \
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
# 5                                 6               61.0
# 6                                 6               63.0
# 7                                 6               42.0
# 8                                 2               61.0
# 9                                 0               69.0
#
#    Extracurricular Activities_No  Extracurricular Activities_Yes
# 0                              0                               1
# 1                              1                               0
# 2                              0                               1
# 3                              0                               1
# 4                              1                               0
# 5                              1                               0
# 6                              0                               1
# 7                              0                               1
# 8                              1                               0
# 9                              1                               0

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.7)

# %%
xtrain
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 4266       1.548079        -1.468485    -0.902247
# 2800       1.548079        -1.526206    -0.313179
# 1296       0.003052         0.494028     0.864957
# 199        1.161822         1.359843     0.275889
# 9830       1.548079         1.071238     0.864957
# ...             ...              ...          ...
# 457        1.548079        -0.140903    -1.491315
# 6134       0.775566         1.186680     0.275889
# 1743       0.389309         0.955796     0.275889
# 9609      -0.769462        -0.544950     0.864957
# 6543       1.161822        -1.064438    -1.491315
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 4266                          1.191813                       0.990022
# 2800                          0.494234                      -1.010078
# 1296                         -1.249715                       0.990022
# 199                          -0.900925                       0.990022
# 9830                         -0.900925                       0.990022
# ...                                ...                            ...
# 457                          -0.552136                      -1.010078
# 6134                          0.145444                      -1.010078
# 1743                         -1.598505                       0.990022
# 9609                         -1.249715                      -1.010078
# 6543                         -1.598505                      -1.010078
#
#       Extracurricular Activities_Yes
# 4266                       -0.990022
# 2800                        1.010078
# 1296                       -0.990022
# 199                        -0.990022
# 9830                       -0.990022
# ...                              ...
# 457                         1.010078
# 6134                        1.010078
# 1743                       -0.990022
# 9609                        1.010078
# 6543                        1.010078
#
# [6911 rows x 6 columns]

# %%
ytrain
# Out:
# 4266    38.0
# 2800    40.0
# 1296    65.0
# 199     89.0
# 9830    84.0
#         ...
# 457     64.0
# 6134    79.0
# 1743    76.0
# 9609    37.0
# 6543    43.0
# Name: Performance Index, Length: 6911, dtype: float64

# %%
xtest
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 216        1.548079        -1.583927     0.864957
# 5321      -1.155719        -0.775834    -0.902247
# 3528      -1.541976         1.417564    -0.902247
# 8420       1.548079        -1.295322     0.864957
# 3764      -0.769462         0.320865     1.454025
# ...             ...              ...          ...
# 3465      -1.155719         1.533006     1.454025
# 3          0.003052        -1.006717    -0.902247
# 3323       1.548079        -0.198624     0.864957
# 329        0.389309        -0.371787    -1.491315
# 3986       0.003052         0.840354    -1.491315
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 216                           0.494234                       0.990022
# 5321                         -0.552136                      -1.010078
# 3528                         -1.249715                       0.990022
# 8420                          1.191813                       0.990022
# 3764                         -0.203346                      -1.010078
# ...                                ...                            ...
# 3465                          1.191813                      -1.010078
# 3                            -0.900925                      -1.010078
# 3323                          0.145444                       0.990022
# 329                          -0.552136                       0.990022
# 3986                          0.843023                      -1.010078
#
#       Extracurricular Activities_Yes
# 216                        -0.990022
# 5321                        1.010078
# 3528                       -0.990022
# 8420                       -0.990022
# 3764                        1.010078
# ...                              ...
# 3465                        1.010078
# 3                           1.010078
# 3323                       -0.990022
# 329                        -0.990022
# 3986                        1.010078
#
# [2962 rows x 6 columns]

# %%
ytest
# Out:
# 216     41.0
# 5321    31.0
# 3528    66.0
# 8420    45.0
# 3764    60.0
#         ...
# 3465    75.0
# 3       36.0
# 3323    64.0
# 329     51.0
# 3986    73.0
# Name: Performance Index, Length: 2962, dtype: float64

# %% [markdown]
# # Model building

# %% [markdown]
# **Getting prediction for new test data**

# %% [markdown]
# # Evaluating the Linear regression model
